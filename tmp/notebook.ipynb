# %%
import os
import requests
import time
import json
import csv


class ApiVideoAuth:
    def __init__(self, api_key):
        self.api_key = api_key
        self.access_token = None
        self.refresh_token = None
        self.token_expiration = None
        self.base_url = "https://ws.api.video"
        self.csv_file = "/home/jupyteruser/video_tags.csv"
        self.existing_tags = self._load_existing_tags()

    def authenticate(self):
        url = f"{self.base_url}/auth/api-key"
        headers = {"Content-Type": "application/json"}
        data = {"apiKey": self.api_key}

        response = requests.post(url, json=data, headers=headers)
        if response.status_code == 200:
            token_data = response.json()
            self.access_token = token_data["access_token"]
            self.refresh_token = token_data["refresh_token"]
            self.token_expiration = time.time() + token_data["expires_in"]
        else:
            raise Exception(
                f"Failed to authenticate: {response.status_code} - {response.text}"
            )

    def refresh_access_token(self):
        url = f"{self.base_url}/auth/refresh"
        headers = {
            "Content-Type": "application/json",
            "Accept": "application/json",
        }
        data = {"refreshToken": self.refresh_token}

        response = requests.post(url, json=data, headers=headers)
        if response.status_code == 200:
            token_data = response.json()
            self.access_token = token_data["access_token"]
            self.refresh_token = token_data["refresh_token"]
            self.token_expiration = time.time() + token_data["expires_in"]
        else:
            raise Exception(
                f"Failed to refresh token: {response.status_code} - {response.text}"
            )

    def get_access_token(self):
        if not self.access_token or time.time() >= self.token_expiration:
            print("Token expired or not available, refreshing...")
            self.refresh_access_token()
        return self.access_token

    def _load_existing_tags(self):
        existing_tags = {}
        if os.path.isfile(self.csv_file):
            with open(self.csv_file, "r", newline="") as csvfile:
                reader = csv.reader(csvfile)
                next(reader)  # Skip header
                for row in reader:
                    video_id, tag = row
                    if video_id not in existing_tags:
                        existing_tags[video_id] = set()
                    existing_tags[video_id].add(tag)
        return existing_tags

    def _save_tags_to_csv(self, video_id, tags):
        new_tags = False
        if video_id not in self.existing_tags:
            self.existing_tags[video_id] = set()

        for tag in tags:
            if tag not in self.existing_tags[video_id]:
                self.existing_tags[video_id].add(tag)
                new_tags = True
                with open(self.csv_file, "a", newline="") as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerow([video_id, tag])

        if new_tags:
            print(f"New tags added for video {video_id}")
        else:
            print(f"No new tags for video {video_id}")

    def _make_request(self, method, endpoint, data=None, params=None, files=None):
        url = f"{self.base_url}{endpoint}"
        headers = {"Authorization": f"Bearer {self.get_access_token()}"}

        if data and not files:
            headers["Content-Type"] = "application/json"
            response = requests.request(
                method, url, json=data, params=params, headers=headers
            )
        else:
            response = requests.request(
                method, url, data=data, params=params, files=files, headers=headers
            )

        if response.status_code in [200, 201, 204]:
            return response.json() if response.content else None
        else:
            raise Exception(
                f"API request failed: {response.status_code} - {response.text}"
            )

    # Video endpoints
    def list_videos(self, params=None):
        videos = self._make_request("GET", "/videos", params=params)
        if "data" in videos:
            for video in videos["data"]:
                if "videoId" in video and "tags" in video:
                    self._save_tags_to_csv(video["videoId"], video["tags"])
        return videos

    def create_video(self, data):
        return self._make_request("POST", "/videos", data=data)

    def get_video(self, video_id):
        return self._make_request("GET", f"/videos/{video_id}")

    def update_video(self, video_id, data):
        return self._make_request("PATCH", f"/videos/{video_id}", data=data)

    def delete_video(self, video_id):
        return self._make_request("DELETE", f"/videos/{video_id}")

    def upload_video(self, video_id, file_path):
        with open(file_path, "rb") as file:
            return self._make_request(
                "POST", f"/videos/{video_id}/source", files={"file": file}
            )

    # Live stream endpoints
    def create_live_stream(self, data):
        return self._make_request("POST", "/live-streams", data=data)

    def get_live_stream(self, live_stream_id):
        return self._make_request("GET", f"/live-streams/{live_stream_id}")

    def update_live_stream(self, live_stream_id, data):
        return self._make_request("PATCH", f"/live-streams/{live_stream_id}", data=data)

    def delete_live_stream(self, live_stream_id):
        return self._make_request("DELETE", f"/live-streams/{live_stream_id}")

    # Player endpoints
    def create_player(self, data):
        return self._make_request("POST", "/players", data=data)

    def get_player(self, player_id):
        return self._make_request("GET", f"/players/{player_id}")

    def update_player(self, player_id, data):
        return self._make_request("PATCH", f"/players/{player_id}", data=data)

    def delete_player(self, player_id):
        return self._make_request("DELETE", f"/players/{player_id}")

    # Captions endpoints
    def upload_caption(self, video_id, language, file_path):
        with open(file_path, "rb") as file:
            return self._make_request(
                "POST", f"/videos/{video_id}/captions/{language}", files={"file": file}
            )

    def get_caption(self, video_id, language):
        return self._make_request("GET", f"/videos/{video_id}/captions/{language}")

    def update_caption(self, video_id, language, data):
        return self._make_request(
            "PATCH", f"/videos/{video_id}/captions/{language}", data=data
        )

    def delete_caption(self, video_id, language):
        return self._make_request("DELETE", f"/videos/{video_id}/captions/{language}")

    # Chapters endpoints
    def upload_chapter(self, video_id, language, file_path):
        with open(file_path, "rb") as file:
            return self._make_request(
                "POST", f"/videos/{video_id}/chapters/{language}", files={"file": file}
            )

    def get_chapter(self, video_id, language):
        return self._make_request("GET", f"/videos/{video_id}/chapters/{language}")

    def delete_chapter(self, video_id, language):
        return self._make_request("DELETE", f"/videos/{video_id}/chapters/{language}")

    # Watermark endpoints
    def upload_watermark(self, file_path):
        with open(file_path, "rb") as file:
            return self._make_request("POST", "/watermarks", files={"file": file})

    def delete_watermark(self, watermark_id):
        return self._make_request("DELETE", f"/watermarks/{watermark_id}")

    # Analytics endpoints
    def get_video_analytics(self, video_id, params=None):
        return self._make_request("GET", f"/analytics/videos/{video_id}", params=params)

    def get_live_stream_analytics(self, live_stream_id, params=None):
        return self._make_request(
            "GET", f"/analytics/live-streams/{live_stream_id}", params=params
        )

    # Helper functions
    def get_all_videos_for_person(self, person_names):
        tags = person_names if isinstance(person_names, list) else [person_names]
        return self.list_videos(params={"tags": tags})

# %%
import csv
import json
from api_video import ApiVideoAuth

# Initialize the ApiVideoAuth class
API_KEY = (
    "dHGElV8BsOEzcjGM1eLOy5LYnrx0TyqR45TgfjMBPL2"  # Replace with your actual API key
)
api_video = ApiVideoAuth("dHGElV8BsOEzcjGM1eLOy5LYnrx0TyqR45TgfjMBPL2")
api_video.authenticate()


def read_csv(file_path):
    activities = {}
    with open(file_path, "r") as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            video_id = row["index"].split("_")[0]
            if video_id not in activities:
                activities[video_id] = []

            # Add the 'type' key based on the 'activity' field
            row["type"] = row["activity"].lower()

            activities[video_id].append(row)
    return activities


count = 0


def update_video_metadata(video_id, activities):

    # Convert activities to JSON string
    activities_json = json.dumps(activities)

    old_metadata = api_video.get_video(video_id)["metadata"]
    print(old_metadata)

    # Push a new object into old_metadata array
    old_metadata.append({"key": "activities", "value": activities_json})
    # Remove the item with key 'activities' from old_metadata in place
    # old_metadata = [item for item in old_metadata if item.get('key') != 'activities']

    # Prepare metadata update
    metadata = {"metadata": old_metadata}

    try:
        # Update video metadata
        res = api_video.update_video(video_id, data={"metadata": old_metadata})
        print(res)
        print(f"Updated metadata for video {video_id}")
    except Exception as e:
        print(f"Error updating metadata for video {video_id}: {str(e)}")


def main():
    csv_file_path = "./activity_moments_clean_v2.csv"

    # Read and aggregate activities from CSV
    activities_by_video = read_csv(csv_file_path)

    # Update metadata for each video
    for video_id, activities in activities_by_video.items():
        update_video_metadata(video_id, activities)
        # print(video_id, activities)


if __name__ == "__main__":
    main()
# Out:
# [{'key': 'summary', 'value': 'In this meeting, Kanishka Rao and Bill Landi discuss challenges in their sales strategy, particularly concerning the adoption of their health solution in hospitals, while emphasizing the importance of selling services rather than just technology. They explore issues around engaging clinicians and executives effectively, reviewing past meeting outcomes, and suggest improvements in decision-making processes within their team to foster a more collaborative environment.'}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 11, "segment_id_sequence_end": 13, "speaker_name": "Kanishka Rao", "emotion": "Urgency", "emotion_intensity": 7, "reasoning": "Kanishka expresses a need to move forward with structuring the meeting agenda quickly and emphasizes the importance of upcoming discussions.", "context": "Kanishka is trying to lead the meeting efficiently as he has a time constraint approaching."}, {"sequence_id": 2, "segment_id_sequence_start": 51, "segment_id_sequence_end": 53, "speaker_name": "Kanishka Rao", "emotion": "Frustration", "emotion_intensity": 8, "reasoning": "Kanishka expresses dissatisfaction with the current inability to convince others about the solutions and reflects on a previous meeting\'s lack of productive outcomes.", "context": "In discussing previous meetings\' effectiveness, Kanishka shows frustration over missed opportunities in discussions."}, {"sequence_id": 3, "segment_id_sequence_start": 33, "segment_id_sequence_end": 35, "speaker_name": "Kanishka Rao", "emotion": "Concern", "emotion_intensity": 7, "reasoning": "Kanishka displays concern over past strategies and their outcomes regarding asthma as a market segment.", "context": "The dialogue revolves around the importance of ensuring effective sales strategies that align appropriately with health systems."}, {"sequence_id": 4, "segment_id_sequence_start": 394, "segment_id_sequence_end": 396, "speaker_name": "Kanishka Rao", "emotion": "Concern", "emotion_intensity": 6, "reasoning": "Kanishka brings up transparency issues and emphasizes needing an action-oriented approach from the team.", "context": "The team is discussing the need for clearer communication regarding decision-making processes to improve effectiveness."}, {"sequence_id": 5, "segment_id_sequence_start": 448, "segment_id_sequence_end": 450, "speaker_name": "Bill Landi", "emotion": "Support", "emotion_intensity": 8, "reasoning": "Bill shows support for Kanishka\'s perspective on needing regular meetings to discuss decisions actively.", "context": "Bill is engaging positively with Kanishka\'s ideas, emphasizing teamwork and the importance of discussing decisions and project statuses."}]}'}]
# {'videoId': 'vi4flB6clm0iow6IFTbC7emI', 'title': 'Bill/Kanishka weekly meeting - Sept 17', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-09-28T17:43:14+00:00', 'createdAt': '2024-09-28T17:43:14+00:00', 'updatedAt': '2024-10-15T19:27:45+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'summary', 'value': 'In this meeting, Kanishka Rao and Bill Landi discuss challenges in their sales strategy, particularly concerning the adoption of their health solution in hospitals, while emphasizing the importance of selling services rather than just technology. They explore issues around engaging clinicians and executives effectively, reviewing past meeting outcomes, and suggest improvements in decision-making processes within their team to foster a more collaborative environment.'}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 11, "segment_id_sequence_end": 13, "speaker_name": "Kanishka Rao", "emotion": "Urgency", "emotion_intensity": 7, "reasoning": "Kanishka expresses a need to move forward with structuring the meeting agenda quickly and emphasizes the importance of upcoming discussions.", "context": "Kanishka is trying to lead the meeting efficiently as he has a time constraint approaching."}, {"sequence_id": 2, "segment_id_sequence_start": 51, "segment_id_sequence_end": 53, "speaker_name": "Kanishka Rao", "emotion": "Frustration", "emotion_intensity": 8, "reasoning": "Kanishka expresses dissatisfaction with the current inability to convince others about the solutions and reflects on a previous meeting\'s lack of productive outcomes.", "context": "In discussing previous meetings\' effectiveness, Kanishka shows frustration over missed opportunities in discussions."}, {"sequence_id": 3, "segment_id_sequence_start": 33, "segment_id_sequence_end": 35, "speaker_name": "Kanishka Rao", "emotion": "Concern", "emotion_intensity": 7, "reasoning": "Kanishka displays concern over past strategies and their outcomes regarding asthma as a market segment.", "context": "The dialogue revolves around the importance of ensuring effective sales strategies that align appropriately with health systems."}, {"sequence_id": 4, "segment_id_sequence_start": 394, "segment_id_sequence_end": 396, "speaker_name": "Kanishka Rao", "emotion": "Concern", "emotion_intensity": 6, "reasoning": "Kanishka brings up transparency issues and emphasizes needing an action-oriented approach from the team.", "context": "The team is discussing the need for clearer communication regarding decision-making processes to improve effectiveness."}, {"sequence_id": 5, "segment_id_sequence_start": 448, "segment_id_sequence_end": 450, "speaker_name": "Bill Landi", "emotion": "Support", "emotion_intensity": 8, "reasoning": "Bill shows support for Kanishka\'s perspective on needing regular meetings to discuss decisions actively.", "context": "Bill is engaging positively with Kanishka\'s ideas, emphasizing teamwork and the importance of discussing decisions and project statuses."}]}'}, {'key': 'activities', 'value': '[{"index": "vi4flB6clm0iow6IFTbC7emI_Delegation_1", "sequence_id": "1", "segment_id_sequence_start": "31", "segment_id_sequence_end": "41", "summary": "Kanishka delegates the responsibility of determining the sales strategy to Bill, emphasizing the need for a services sale approach based on their discussion about market challenges.", "title": "Sales Strategy Discussion", "segment_start_timestamp": "18:37.013", "segment_end_timestamp": "21:38.117", "segment_start_timestamp_in_seconds": "1117", "segment_end_timestamp_in_seconds": "1298", "video_id": "vi4flB6clm0iow6IFTbC7emI", "activity_type": "Not Delegation", "activity_reasoning": "Kanishka Rao is discussing strategies and conclusions but is not delegating tasks to others or receiving tasks from others.", "target_person_type": "No Delegation", "target_person_reasoning": "Kanishka Rao is discussing strategies and conclusions b ...
# Updated metadata for video vi4flB6clm0iow6IFTbC7emI
# [{'key': 'summary', 'value': "In this meeting, Bill Landi and Kanishka Rao discussed various ongoing projects, notably focusing on the metrics framework to track performance and outcomes for their initiatives, including the need for analytics to compare exacerbation and hospitalization rates. They addressed challenges surrounding accountability and communication within their team, particularly concerning Kanishka's role in overseeing multiple tasks, as well as challenges with his father's focus and productivity in decision-making processes."}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 1, "segment_id_sequence_end": 3, "speaker_name": "Bill Landi", "emotion": "Apologetic", "emotion_intensity": 7, "reasoning": "Bill expresses apologies and seems to attribute some fault to himself for delaying the meeting.", "context": "Initial greetings and Bill realizing he took longer than expected to join the meeting."}, {"sequence_id": 2, "segment_id_sequence_start": 5, "segment_id_sequence_end": 7, "speaker_name": "Bill Landi", "emotion": "Frustration", "emotion_intensity": 6, "reasoning": "Bill shows frustration about struggling with metrics and communicates it as a high priority problem.", "context": "Discussion around Bill trying to manage metric-related issues and feeling that it\'s the main stressful task."}, {"sequence_id": 3, "segment_id_sequence_start": 19, "segment_id_sequence_end": 23, "speaker_name": "Kanishka Rao", "emotion": "Hopefulness", "emotion_intensity": 5, "reasoning": "Kanishka is upbeat when discussing potential connections for his sister\'s accounting needs, showing a desire for collaboration.", "context": "Kanishka is discussing the possibility of connecting his sister with Bill\'s relative for an accounting position, suggesting a supportive relationship."}, {"sequence_id": 4, "segment_id_sequence_start": 74, "segment_id_sequence_end": 76, "speaker_name": "Kanishka Rao", "emotion": "Satisfaction", "emotion_intensity": 6, "reasoning": "Kanishka reflects on the costs of trips and shows a positive outlook on his investment strategy.", "context": "Reflecting on personal finance and investment approaches, expressing satisfaction over his financial decisions."}, {"sequence_id": 5, "segment_id_sequence_start": 100, "segment_id_sequence_end": 102, "speaker_name": "Bill Landi", "emotion": "Caution", "emotion_intensity": 8, "reasoning": "Bill expresses concern about the unpredictability of market timing, acknowledging the emotional aspect behind investment decisions.", "context": "A discussion on the stock market, emphasizing the importance of long-term views instead of short-term fluctuations."}, {"sequence_id": 6, "segment_id_sequence_start": 106, "segment_id_sequence_end": 110, "speaker_name": "Kanishka Rao", "emotion": "Determination", "emotion_intensity": 7, "reasoning": "Kanishka insists on the significance of the metrics project and expresses urgency and a sense of responsibility.", "context": "Kanishka emphasizes the importance of getting timely results from their metrics-related work."}]}'}]
# {'videoId': 'vi6TBTdOQ3bkW2b7ku6xtvbK', 'title': 'Bill/Kanishka weekly meeting - Sept 10', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-09-28T17:46:29+00:00', 'createdAt': '2024-09-28T17:46:29+00:00', 'updatedAt': '2024-10-15T19:27:47+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'summary', 'value': "In this meeting, Bill Landi and Kanishka Rao discussed various ongoing projects, notably focusing on the metrics framework to track performance and outcomes for their initiatives, including the need for analytics to compare exacerbation and hospitalization rates. They addressed challenges surrounding accountability and communication within their team, particularly concerning Kanishka's role in overseeing multiple tasks, as well as challenges with his father's focus and productivity in decision-making processes."}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 1, "segment_id_sequence_end": 3, "speaker_name": "Bill Landi", "emotion": "Apologetic", "emotion_intensity": 7, "reasoning": "Bill expresses apologies and seems to attribute some fault to himself for delaying the meeting.", "context": "Initial greetings and Bill realizing he took longer than expected to join the meeting."}, {"sequence_id": 2, "segment_id_sequence_start": 5, "segment_id_sequence_end": 7, "speaker_name": "Bill Landi", "emotion": "Frustration", "emotion_intensity": 6, "reasoning": "Bill shows frustration about struggling with metrics and communicates it as a high priority problem.", "context": "Discussion around Bill trying to manage metric-related issues and feeling that it\'s the main stressful task."}, {"sequence_id": 3, "segment_id_sequence_start": 19, "segment_id_sequence_end": 23, "speaker_name": "Kanishka Rao", "emotion": "Hopefulness", "emotion_intensity": 5, "reasoning": "Kanishka is upbeat when discussing potential connections for his sister\'s accounting needs, showing a desire for collaboration.", "context": "Kanishka is discussing the possibility of connecting his sister with Bill\'s relative for an accounting position, suggesting a supportive relationship."}, {"sequence_id": 4, "segment_id_sequence_start": 74, "segment_id_sequence_end": 76, "speaker_name": "Kanishka Rao", "emotion": "Satisfaction", "emotion_intensity": 6, "reasoning": "Kanishka reflects on the costs of trips and shows a positive outlook on his investment strategy.", "context": "Reflecting on personal finance and investment approaches, expressing satisfaction over his financial decisions."}, {"sequence_id": 5, "segment_id_sequence_start": 100, "segment_id_sequence_end": 102, "speaker_name": "Bill Landi", "emotion": "Caution", "emotion_intensity": 8, "reasoning": "Bill expresses concern about the unpredictability of market timing, acknowledging the emotional aspect behind investment decisions.", "context": "A discussion on the stock market, emphasizing the importance of long-term views instead of short-term fluctuations."}, {"sequence_id": 6, "segment_id_sequence_start": 106, "segment_id_sequence_end": 110, "speaker_name": "Kanishka Rao", "emotion": "Determination", "emotion_intensity": 7, "reasoning": "Kanishka insists on the significance of the metrics project and expresses urgency and a sense of responsibility.", "context": "Kanishka emphasizes the importance of getting timely results from their metrics-related work."}]}'}, {'key': 'activities', 'value': '[{"index": "vi6TBTdOQ3bkW2b7ku6xtvbK_Delegation_1", "sequence_id": "1", "segment_id_sequence_start": "13", "segment_id_sequence_end": "21", "summary": "Bill suggests Kanishka\'s sister talk to Carol about accounting, indicating Carol\'s availability and qualifications, thus delegating the task of connecting them.", "title": "Delegating Accounting Connection", "segment_start_timestamp": "13:16.768", "segment_end_timestamp": "15:09.884", "segment_start_timestamp_in_seconds": "796", "segment_end_timestamp_in_seconds": " ...
# Updated metadata for video vi6TBTdOQ3bkW2b7ku6xtvbK
# [{'key': 'summary', 'value': 'In this meeting, participants discussed a proposed budget allocation for Care Gnostics, aiming to secure funding from leadership to support a service model targeting care gaps in health systems. They outlined strategies for generating revenue, enhancing their fundraising narrative for Series A, and explored potential applications of their solution in chronic disease management, particularly for COPD. The conversation also involved identifying economic buyers and establishing partnerships for piloting their solutions.'}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 1, "segment_id_sequence_end": 2, "speaker_name": "Kanishka Rao", "emotion": "Hopefulness", "emotion_intensity": 7, "reasoning": "Kanishka is discussing a potential funding venture which he seems optimistic about, indicating a future-focused mindset.", "context": "Kanishka is outlining the plans for pitching a proposal for care gnostics, reflecting a positive outlook on securing funding."}, {"sequence_id": 2, "segment_id_sequence_start": 12, "segment_id_sequence_end": 12, "speaker_name": "Kanishka Rao", "emotion": "Concern", "emotion_intensity": 8, "reasoning": "Kanishka expresses serious doubts about the consequences if the proposal does not come through, which indicates a high level of concern and urgency.", "context": "Discussing the implications of the funding plan being unsuccessful, showing the pressure under which they\\u2019re operating."}, {"sequence_id": 3, "segment_id_sequence_start": 20, "segment_id_sequence_end": 20, "speaker_name": "Kanishka Rao", "emotion": "Frustration", "emotion_intensity": 6, "reasoning": "The use of phrases reflecting frustration indicates Kanishka\'s vexation regarding the need to reassess strategies if the current plan doesn\'t yield results.", "context": "Kanishka is reflecting on the potential need to rethink their strategy should the funding not go through."}, {"sequence_id": 4, "segment_id_sequence_start": 168, "segment_id_sequence_end": 169, "speaker_name": "Soham Shah", "emotion": "Confidence", "emotion_intensity": 7, "reasoning": "Soham shows confidence in the approach by suggesting they should pitch to the mentioned medical professional directly.", "context": "Soham discusses the strategy to approach a key contact in the healthcare sector, reflecting confidence in their proposal."}, {"sequence_id": 5, "segment_id_sequence_start": 272, "segment_id_sequence_end": 277, "speaker_name": "Kanishka Rao", "emotion": "Gratitude", "emotion_intensity": 6, "reasoning": "Kanishka expresses appreciation to Soham for taking the time to discuss strategies and share insights, indicating a warm, positive closure to the meeting.", "context": "Kanishka is thanking Soham for his input, highlighting a sense of mutual support and teamwork."}]}'}]
# {'videoId': 'vi42vP3lFwcaZP6hH82M5wZE', 'title': 'Soham <> Kanishka check-in', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-09-28T17:48:16+00:00', 'createdAt': '2024-09-28T17:48:16+00:00', 'updatedAt': '2024-10-15T19:27:49+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'summary', 'value': 'In this meeting, participants discussed a proposed budget allocation for Care Gnostics, aiming to secure funding from leadership to support a service model targeting care gaps in health systems. They outlined strategies for generating revenue, enhancing their fundraising narrative for Series A, and explored potential applications of their solution in chronic disease management, particularly for COPD. The conversation also involved identifying economic buyers and establishing partnerships for piloting their solutions.'}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 1, "segment_id_sequence_end": 2, "speaker_name": "Kanishka Rao", "emotion": "Hopefulness", "emotion_intensity": 7, "reasoning": "Kanishka is discussing a potential funding venture which he seems optimistic about, indicating a future-focused mindset.", "context": "Kanishka is outlining the plans for pitching a proposal for care gnostics, reflecting a positive outlook on securing funding."}, {"sequence_id": 2, "segment_id_sequence_start": 12, "segment_id_sequence_end": 12, "speaker_name": "Kanishka Rao", "emotion": "Concern", "emotion_intensity": 8, "reasoning": "Kanishka expresses serious doubts about the consequences if the proposal does not come through, which indicates a high level of concern and urgency.", "context": "Discussing the implications of the funding plan being unsuccessful, showing the pressure under which they\\u2019re operating."}, {"sequence_id": 3, "segment_id_sequence_start": 20, "segment_id_sequence_end": 20, "speaker_name": "Kanishka Rao", "emotion": "Frustration", "emotion_intensity": 6, "reasoning": "The use of phrases reflecting frustration indicates Kanishka\'s vexation regarding the need to reassess strategies if the current plan doesn\'t yield results.", "context": "Kanishka is reflecting on the potential need to rethink their strategy should the funding not go through."}, {"sequence_id": 4, "segment_id_sequence_start": 168, "segment_id_sequence_end": 169, "speaker_name": "Soham Shah", "emotion": "Confidence", "emotion_intensity": 7, "reasoning": "Soham shows confidence in the approach by suggesting they should pitch to the mentioned medical professional directly.", "context": "Soham discusses the strategy to approach a key contact in the healthcare sector, reflecting confidence in their proposal."}, {"sequence_id": 5, "segment_id_sequence_start": 272, "segment_id_sequence_end": 277, "speaker_name": "Kanishka Rao", "emotion": "Gratitude", "emotion_intensity": 6, "reasoning": "Kanishka expresses appreciation to Soham for taking the time to discuss strategies and share insights, indicating a warm, positive closure to the meeting.", "context": "Kanishka is thanking Soham for his input, highlighting a sense of mutual support and teamwork."}]}'}, {'key': 'activities', 'value': '[{"index": "vi42vP3lFwcaZP6hH82M5wZE_Delegation_1", "sequence_id": "1", "segment_id_sequence_start": "50", "segment_id_sequence_end": "50", "summary": "Kanishka asks Soham to review a COPD dashboard and provide feedback, indicating delegation of the task to Soham.", "title": "Review of COPD Dashboard", "segment_start_timestamp": "16:33.363", "segment_end_timestamp": "16:32.903", "segment_start_timestamp_in_seconds": "993", "segment_end_timestamp_in_seconds": "992", "video_id": "vi42vP3lFwcaZP6hH82M5wZE", "activity_type": "Guidance with Delegation", "activity_reasoning": "Kanishka Rao is delegating a task by asking someone to take a quick look at the COPD dashboard and provide comments, while also offering guidance on what to focus on, indicating a clear assignment of respon ...
# Updated metadata for video vi42vP3lFwcaZP6hH82M5wZE
# [{'key': 'summary', 'value': "In this meeting, the participants discuss the use of transcription services, specifically Otter AI, and the implications of data deletion and recovery, especially in the context of sensitive HR topics. They also share updates on a recent development related to a colleague's departure, including the details surrounding legal fines and how to communicate this within the leadership team."}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 19, "segment_id_sequence_end": 21, "speaker_name": "Bharat Rao", "emotion": "Shock", "emotion_intensity": 8, "reasoning": "Bharat Rao expresses surprise and a strong emotional response to the implications of a decision related to a colleague\'s employment.", "context": "The revelation of sensitive information about a colleague\'s dismissal based on significant financial penalties is discussed."}, {"sequence_id": 2, "segment_id_sequence_start": 25, "segment_id_sequence_end": 25, "speaker_name": "Kanishka Rao", "emotion": "Astonishment", "emotion_intensity": 7, "reasoning": "Kanishka uses strong language (\'Holy shit\') to express his disbelief, highlighting his emotional reaction to the news.", "context": "Kanishka reacts to shocking news shared by Bharat about their colleague, indicating a shared sentiment of surprise among the group."}, {"sequence_id": 3, "segment_id_sequence_start": 26, "segment_id_sequence_end": 28, "speaker_name": "Bharat Rao", "emotion": "Urgency", "emotion_intensity": 9, "reasoning": "Bharat expresses a sense of urgency in wanting to share important news, indicating his concern about its implications.", "context": "Bharat is eager to communicate crucial developments regarding a colleague\'s situation, indicating the gravity of the matter."}]}'}, {'key': 'activities', 'value': '[{"index": "vi4jzbO8E3eWXzvCGz7XNI0w_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "1", "segment_id_sequence_end": "3", "summary": "Bharat discusses the importance of standardizing recording practices and expresses concerns about data privacy, prompting feedback from Kanishka about his own usage of transcription tools.", "title": "Discussion on Recording Practices", "segment_start_timestamp": "00:48.376", "segment_end_timestamp": "01:23.990", "segment_start_timestamp_in_seconds": "48", "segment_end_timestamp_in_seconds": "83", "video_id": "vi4jzbO8E3eWXzvCGz7XNI0w", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is not involved in the interaction as he is merely stating his intention to try something for a couple of weeks without providing or receiving feedback.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not involved in the interaction as he is merely stating his intention to try something for a couple of weeks without providing or receiving feedback.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi4jzbO8E3eWXzvCGz7XNI0w#;t=48", "type": "feedback"}, {"index": "vi4jzbO8E3eWXzvCGz7XNI0w_Feedback_2", "sequence_id": "2", "segment_id_sequence_start": "8", "segment_id_sequence_end": "17", "summary": "Bharat shares a public information piece related to a colleague\'s departure, eliciting reactions from Kanishka and Sriram, indicating a shared concern and need for communication.", "title": "Sharing Sensitive Information", "segment_start_timestamp": "02:36.510", "segment_end_timestamp": "03:27.870", "segment_start_timestamp_in_seconds": "156", "segment_end_timestamp_in_seconds": "207", "video_id": "vi4jzbO8E3eWXzvCGz7XNI0w", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is primarily reacting to the conversation and does not provide any feedback or guidance, as he is not involved in the main discussion.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not involved in the interaction as he is primarily reacting to what Bharat Rao is saying and does not provide any feedback  ...
# {'videoId': 'vi4jzbO8E3eWXzvCGz7XNI0w', 'title': 'Leadership Meeting - Sept 13', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-09-28T17:45:32+00:00', 'createdAt': '2024-09-28T17:45:32+00:00', 'updatedAt': '2024-10-15T19:27:50+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'summary', 'value': "In this meeting, the participants discuss the use of transcription services, specifically Otter AI, and the implications of data deletion and recovery, especially in the context of sensitive HR topics. They also share updates on a recent development related to a colleague's departure, including the details surrounding legal fines and how to communicate this within the leadership team."}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 19, "segment_id_sequence_end": 21, "speaker_name": "Bharat Rao", "emotion": "Shock", "emotion_intensity": 8, "reasoning": "Bharat Rao expresses surprise and a strong emotional response to the implications of a decision related to a colleague\'s employment.", "context": "The revelation of sensitive information about a colleague\'s dismissal based on significant financial penalties is discussed."}, {"sequence_id": 2, "segment_id_sequence_start": 25, "segment_id_sequence_end": 25, "speaker_name": "Kanishka Rao", "emotion": "Astonishment", "emotion_intensity": 7, "reasoning": "Kanishka uses strong language (\'Holy shit\') to express his disbelief, highlighting his emotional reaction to the news.", "context": "Kanishka reacts to shocking news shared by Bharat about their colleague, indicating a shared sentiment of surprise among the group."}, {"sequence_id": 3, "segment_id_sequence_start": 26, "segment_id_sequence_end": 28, "speaker_name": "Bharat Rao", "emotion": "Urgency", "emotion_intensity": 9, "reasoning": "Bharat expresses a sense of urgency in wanting to share important news, indicating his concern about its implications.", "context": "Bharat is eager to communicate crucial developments regarding a colleague\'s situation, indicating the gravity of the matter."}]}'}, {'key': 'activities', 'value': '[{"index": "vi4jzbO8E3eWXzvCGz7XNI0w_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "1", "segment_id_sequence_end": "3", "summary": "Bharat discusses the importance of standardizing recording practices and expresses concerns about data privacy, prompting feedback from Kanishka about his own usage of transcription tools.", "title": "Discussion on Recording Practices", "segment_start_timestamp": "00:48.376", "segment_end_timestamp": "01:23.990", "segment_start_timestamp_in_seconds": "48", "segment_end_timestamp_in_seconds": "83", "video_id": "vi4jzbO8E3eWXzvCGz7XNI0w", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is not involved in the interaction as he is merely stating his intention to try something for a couple of weeks without providing or receiving feedback.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not involved in the interaction as he is merely stating his intention to try something for a couple of weeks without providing or receiving feedback.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi4jzbO8E3eWXzvCGz7XNI0w#;t=48", "type": "feedback"}, {"index": "vi4jzbO8E3eWXzvCGz7XNI0w_Feedback_2", "sequence_id": "2", "segment_id_sequence_start": "8", "segment_id_sequence_end": "17", "summary": "Bharat shares a public information piece related to a colleague\'s departure, eliciting reactions from Kanishka and Sriram, indicating a shared concern and need for communication.", "title": "Sharing Sensitive Information", "segment_start_timestamp": "02:36.510", "segment_end_timestamp": "03:27.870", "segment_start_timestamp_in_seconds": "156", "segment_end_timestamp_in_seconds": "207", "video_id": "vi4jzbO8E3eWXzvCGz7XNI0w", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is primarily reactin ...
# Updated metadata for video vi4jzbO8E3eWXzvCGz7XNI0w
# [{'key': 'summary', 'value': 'In this meeting, participants discussed updates on strategic priorities, particularly focusing on health system sales, upcoming conferences, and addressing contractual obligations with various stakeholders. They also emphasized the need for alignment on project timelines, resource allocation, and the importance of achieving specific sales goals within the next month, while considering the implications of a potential regulatory audit regarding compliance and intellectual property concerns.'}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 1, "segment_id_sequence_end": 3, "speaker_name": "Bill Landi", "emotion": "Frustration", "emotion_intensity": 7, "reasoning": "Bill expresses frustration in response to the ongoing technical discussion, using phrases like \'that joins before he does\' which implies confusion and dissatisfaction with the collaboration process.", "context": "The beginning of the meeting involves confusion about how the recording is triggered, indicating a lack of clarity in the technical aspects of the meeting setup."}, {"sequence_id": 2, "segment_id_sequence_start": 31, "segment_id_sequence_end": 35, "speaker_name": "Kanishka Rao", "emotion": "Determination", "emotion_intensity": 8, "reasoning": "Kanishka speaks with a sense of urgency about the priorities for the upcoming months, using phrases like \'we need to think twice\' and \'how we\'re getting to where we need to get\' which clearly demonstrates his determination to drive results.", "context": "Discussion around the company\'s priorities and the need to focus on achieving key sales targets before the year\'s end."}, {"sequence_id": 3, "segment_id_sequence_start": 245, "segment_id_sequence_end": 247, "speaker_name": "Bharat Rao", "emotion": "Relief", "emotion_intensity": 6, "reasoning": "Bharat expresses relief about the scheduling of meetings, saying \'it\'s good if you could join,\' indicating he feels positive about the team\'s availability to collaborate effectively.", "context": "Bharat is organizing upcoming meetings, feeling satisfied as the logistics start to align for future discussions."}, {"sequence_id": 4, "segment_id_sequence_start": 645, "segment_id_sequence_end": 646, "speaker_name": "Kanishka Rao", "emotion": "Optimism", "emotion_intensity": 9, "reasoning": "Kanishka ends the meeting on a high note with phrases like \'let\'s sell, baby. Sell, sell\' indicating strong optimism about future sales prospects.", "context": "Concluding the meeting, Kanishka encourages the team to be proactive in driving sales forward."}]}'}, {'key': 'activities', 'value': '[{"index": "vi7YPIONLTIkuIc1odaRFv5_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "22", "segment_id_sequence_end": "24", "summary": "Bharat and Kanishka discuss the importance of measuring and improving GDMT, emphasizing its critical role in obtaining a carve-out. Bharat seeks clarity on the priority of these tasks in relation to the carve-out.", "title": "Discussion on GDMT and Carve-Out", "segment_start_timestamp": "05:35.743", "segment_end_timestamp": "06:00.423", "segment_start_timestamp_in_seconds": "335", "segment_end_timestamp_in_seconds": "360", "video_id": "vi7YPIONLTIkuIc1odaRFv5", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is outlining priorities and discussing strategies without engaging in a feedback exchange.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not the primary person giving or receiving feedback in this interaction. Instead, he is outlining priorities and discussing strategies without engaging in a feedback exchange.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi7YPIONLTIkuIc1odaRFv5#;t=335", "type": "feedback"}, {"index": "vi7YPIONLTIkuIc1odaRFv5_Feedback_2", "sequence_id": "2", "segment_id_sequence_start": "32", "segment_id_sequence_end": "34", "summary": "Bill and Kanishka engage i ...
# {'videoId': 'vi7YPIONLTIkuIc1odaRFv5', 'title': 'Leadership Meeting - Sept 9', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-09-28T17:49:22+00:00', 'createdAt': '2024-09-28T17:49:22+00:00', 'updatedAt': '2024-10-15T19:27:52+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'summary', 'value': 'In this meeting, participants discussed updates on strategic priorities, particularly focusing on health system sales, upcoming conferences, and addressing contractual obligations with various stakeholders. They also emphasized the need for alignment on project timelines, resource allocation, and the importance of achieving specific sales goals within the next month, while considering the implications of a potential regulatory audit regarding compliance and intellectual property concerns.'}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 1, "segment_id_sequence_end": 3, "speaker_name": "Bill Landi", "emotion": "Frustration", "emotion_intensity": 7, "reasoning": "Bill expresses frustration in response to the ongoing technical discussion, using phrases like \'that joins before he does\' which implies confusion and dissatisfaction with the collaboration process.", "context": "The beginning of the meeting involves confusion about how the recording is triggered, indicating a lack of clarity in the technical aspects of the meeting setup."}, {"sequence_id": 2, "segment_id_sequence_start": 31, "segment_id_sequence_end": 35, "speaker_name": "Kanishka Rao", "emotion": "Determination", "emotion_intensity": 8, "reasoning": "Kanishka speaks with a sense of urgency about the priorities for the upcoming months, using phrases like \'we need to think twice\' and \'how we\'re getting to where we need to get\' which clearly demonstrates his determination to drive results.", "context": "Discussion around the company\'s priorities and the need to focus on achieving key sales targets before the year\'s end."}, {"sequence_id": 3, "segment_id_sequence_start": 245, "segment_id_sequence_end": 247, "speaker_name": "Bharat Rao", "emotion": "Relief", "emotion_intensity": 6, "reasoning": "Bharat expresses relief about the scheduling of meetings, saying \'it\'s good if you could join,\' indicating he feels positive about the team\'s availability to collaborate effectively.", "context": "Bharat is organizing upcoming meetings, feeling satisfied as the logistics start to align for future discussions."}, {"sequence_id": 4, "segment_id_sequence_start": 645, "segment_id_sequence_end": 646, "speaker_name": "Kanishka Rao", "emotion": "Optimism", "emotion_intensity": 9, "reasoning": "Kanishka ends the meeting on a high note with phrases like \'let\'s sell, baby. Sell, sell\' indicating strong optimism about future sales prospects.", "context": "Concluding the meeting, Kanishka encourages the team to be proactive in driving sales forward."}]}'}, {'key': 'activities', 'value': '[{"index": "vi7YPIONLTIkuIc1odaRFv5_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "22", "segment_id_sequence_end": "24", "summary": "Bharat and Kanishka discuss the importance of measuring and improving GDMT, emphasizing its critical role in obtaining a carve-out. Bharat seeks clarity on the priority of these tasks in relation to the carve-out.", "title": "Discussion on GDMT and Carve-Out", "segment_start_timestamp": "05:35.743", "segment_end_timestamp": "06:00.423", "segment_start_timestamp_in_seconds": "335", "segment_end_timestamp_in_seconds": "360", "video_id": "vi7YPIONLTIkuIc1odaRFv5", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is outlining priorities and discussing strategies without engaging in a feedback exchange.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not the primary person giving or receiving feedback in this interaction. Instead, he is outlining priorities and discussing strategies without engaging i ...
# Updated metadata for video vi7YPIONLTIkuIc1odaRFv5
# [{'key': 'summary', 'value': "In this meeting, the team discussed their priority tasks for the upcoming month, focusing on contractual obligations with health systems and preparations for multiple upcoming conferences. They stressed the importance of securing a budget from AstraZeneca to ensure future projects align with the company's goals, while also debating the timing and prioritization of different initiatives and resource allocation within the team. The conversation highlighted the balance between immediate, tangible outcomes and longer-term strategic goals."}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 53, "segment_id_sequence_end": 60, "speaker_name": "Sriram Krishnan", "emotion": "Frustration", "emotion_intensity": 7, "reasoning": "Sriram expresses irritation about the time management and prioritization of tasks, questioning if GDMT improvement is more important than immediate deadlines for other tasks.", "context": "A discussion on priority tasks and deadlines in a meeting, indicating urgency and concern about misallocated resources."}, {"sequence_id": 2, "segment_id_sequence_start": 142, "segment_id_sequence_end": 142, "speaker_name": "Bill Landi", "emotion": "Concern", "emotion_intensity": 6, "reasoning": "Bill expresses worry about the risk associated with potentially overcommitting without ensuring the team\'s capacity to deliver.", "context": "Bill is assessing the implications of being unable to deliver on commitments and the risks involved in project management."}, {"sequence_id": 3, "segment_id_sequence_start": 440, "segment_id_sequence_end": 440, "speaker_name": "Scott Weissman", "emotion": "Skepticism", "emotion_intensity": 5, "reasoning": "Scott questions the feasibility and prioritization of efforts, indicating doubts about the scalability of current projects.", "context": "Discussion revolves around the company\'s ability to prove its model and successfully implement projects, showing a lack of confidence and clarity in strategy."}, {"sequence_id": 4, "segment_id_sequence_start": 557, "segment_id_sequence_end": 560, "speaker_name": "Sriram Krishnan", "emotion": "Decisiveness", "emotion_intensity": 8, "reasoning": "Sriram asserts the importance of prioritizing immediate goals while still acknowledging the value of other tasks.", "context": "Sriram emphasizes the need to focus priorities clearly, signifying leadership decisiveness amidst project complexities."}]}'}]
# {'videoId': 'vi1GPAuvhakg74TUpNoMMUvc', 'title': 'Leadership sync on Sept priorities', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-09-28T17:51:17+00:00', 'createdAt': '2024-09-28T17:51:17+00:00', 'updatedAt': '2024-10-15T19:27:53+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'summary', 'value': "In this meeting, the team discussed their priority tasks for the upcoming month, focusing on contractual obligations with health systems and preparations for multiple upcoming conferences. They stressed the importance of securing a budget from AstraZeneca to ensure future projects align with the company's goals, while also debating the timing and prioritization of different initiatives and resource allocation within the team. The conversation highlighted the balance between immediate, tangible outcomes and longer-term strategic goals."}, {'key': 'emotions', 'value': '{"emotion_sequences": [{"sequence_id": 1, "segment_id_sequence_start": 53, "segment_id_sequence_end": 60, "speaker_name": "Sriram Krishnan", "emotion": "Frustration", "emotion_intensity": 7, "reasoning": "Sriram expresses irritation about the time management and prioritization of tasks, questioning if GDMT improvement is more important than immediate deadlines for other tasks.", "context": "A discussion on priority tasks and deadlines in a meeting, indicating urgency and concern about misallocated resources."}, {"sequence_id": 2, "segment_id_sequence_start": 142, "segment_id_sequence_end": 142, "speaker_name": "Bill Landi", "emotion": "Concern", "emotion_intensity": 6, "reasoning": "Bill expresses worry about the risk associated with potentially overcommitting without ensuring the team\'s capacity to deliver.", "context": "Bill is assessing the implications of being unable to deliver on commitments and the risks involved in project management."}, {"sequence_id": 3, "segment_id_sequence_start": 440, "segment_id_sequence_end": 440, "speaker_name": "Scott Weissman", "emotion": "Skepticism", "emotion_intensity": 5, "reasoning": "Scott questions the feasibility and prioritization of efforts, indicating doubts about the scalability of current projects.", "context": "Discussion revolves around the company\'s ability to prove its model and successfully implement projects, showing a lack of confidence and clarity in strategy."}, {"sequence_id": 4, "segment_id_sequence_start": 557, "segment_id_sequence_end": 560, "speaker_name": "Sriram Krishnan", "emotion": "Decisiveness", "emotion_intensity": 8, "reasoning": "Sriram asserts the importance of prioritizing immediate goals while still acknowledging the value of other tasks.", "context": "Sriram emphasizes the need to focus priorities clearly, signifying leadership decisiveness amidst project complexities."}]}'}, {'key': 'activities', 'value': '[{"index": "vi1GPAuvhakg74TUpNoMMUvc_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "12", "segment_id_sequence_end": "12", "summary": "Kanishka outlines the priorities for the month, emphasizing the need for feedback from the team on the proposed priorities and their urgency.", "title": "Monthly Priorities Discussion", "segment_start_timestamp": "05:47.949", "segment_end_timestamp": "05:47.845", "segment_start_timestamp_in_seconds": "347", "segment_end_timestamp_in_seconds": "347", "video_id": "vi1GPAuvhakg74TUpNoMMUvc", "activity_type": "Guidance", "activity_reasoning": "Kanishka Rao is outlining priorities and strategies for the team, suggesting actions to take, such as starting conversations about improving solutions and prioritizing tasks, which aligns with offering advice and direction.", "target_person_type": "Giving Feedback", "target_person_reasoning": "Kanishka Rao is the primary person giving feedback in this case because they are outlining priorities and strategies for the team, indicating what needs to be focused on and suggesting actions to take, such as starting conversations about improving solutions and  ...
# Updated metadata for video vi1GPAuvhakg74TUpNoMMUvc
# []
# {'videoId': 'vi6aqbh5ikJLOYkqOdO7TvN1', 'title': 'Sriram <> Kanishka weekly', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-10-08T20:22:49+00:00', 'createdAt': '2024-10-08T20:22:49+00:00', 'updatedAt': '2024-10-15T19:27:54+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'activities', 'value': '[{"index": "vi6aqbh5ikJLOYkqOdO7TvN1_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "15", "segment_id_sequence_end": "19", "summary": "Sriram discusses feedback from Madeline regarding a demo and emphasizes the importance of Kanishka\'s input on the project, indicating a collaborative effort to ensure the demo meets expectations.", "title": "Feedback on Demo Preparation", "segment_start_timestamp": "03:42.380", "segment_end_timestamp": "06:48.424", "segment_start_timestamp_in_seconds": "222", "segment_end_timestamp_in_seconds": "408", "video_id": "vi6aqbh5ikJLOYkqOdO7TvN1", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is primarily asking for a meeting to review something rather than giving or receiving feedback.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not involved in the interaction as he is primarily asking for a meeting to review something rather than giving or receiving feedback.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi6aqbh5ikJLOYkqOdO7TvN1#;t=222", "type": "feedback"}, {"index": "vi6aqbh5ikJLOYkqOdO7TvN1_Feedback_2", "sequence_id": "2", "segment_id_sequence_start": "25", "segment_id_sequence_end": "27", "summary": "Sriram and Kanishka discuss the challenges faced with the stage three identification model and the need for PCPs\' interest, highlighting the feedback from the PCPs as a critical factor in their strategy.", "title": "Challenges with Stage Three Model", "segment_start_timestamp": "08:24.530", "segment_end_timestamp": "09:14.740", "segment_start_timestamp_in_seconds": "504", "segment_end_timestamp_in_seconds": "554", "video_id": "vi6aqbh5ikJLOYkqOdO7TvN1", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is not involved in the interaction as they are merely stating a fact about the deployment of the model without providing or receiving any feedback.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not involved in the interaction as they are merely stating a fact about the deployment of the model without providing or receiving any feedback.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi6aqbh5ikJLOYkqOdO7TvN1#;t=504", "type": "feedback"}, {"index": "vi6aqbh5ikJLOYkqOdO7TvN1_Feedback_3", "sequence_id": "3", "segment_id_sequence_start": "61", "segment_id_sequence_end": "61", "summary": "Kanishka reflects on the need for a focused approach in their strategy, emphasizing the importance of defining clear goals and capabilities, which aligns with feedback received from Bapa.", "title": "Strategic Focus and Feedback", "segment_start_timestamp": "18:27.786", "segment_end_timestamp": "18:27.682", "segment_start_timestamp_in_seconds": "1107", "segment_end_timestamp_in_seconds": "1107", "video_id": "vi6aqbh5ikJLOYkqOdO7TvN1", "activity_type": "Not Feedback", "activity_reasoning": "The segment discusses strategies and opinions regarding CKD and does not involve Kanishka Rao or any direct feedback.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not mentioned in this segment of the transcript, and there is no indication of their involvement in the discussion.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi6aqbh5ikJLOYkqOdO7TvN1#;t=1107", "type": "feedback"}, {"index": "vi6aqbh5ikJLOYkqOdO7TvN1_Feedback_4", "sequence_id": "4", "segment_id_sequence_start": "91", "segment_id_sequence_end": "91", "summary": "Sriram shares his insights on the need for a clear vision and focus, responding to Kanishka\'s feedback about the company\'s direct ...
# Updated metadata for video vi6aqbh5ikJLOYkqOdO7TvN1
# []
# {'videoId': 'vi31gHvd0MMz8FonUstjUyMe', 'title': 'Bill/Kanishka weekly meeting', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-10-08T20:23:51+00:00', 'createdAt': '2024-10-08T20:23:51+00:00', 'updatedAt': '2024-10-15T19:27:56+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'activities', 'value': '[{"index": "vi31gHvd0MMz8FonUstjUyMe_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "9", "segment_id_sequence_end": "13", "summary": "Bill expresses concerns about the organization\'s performance and the interpretation of preliminary data, prompting Kanishka to acknowledge the importance of these concerns and add his own.", "title": "Concerns Over Organizational Performance", "segment_start_timestamp": "01:06.060", "segment_end_timestamp": "03:14.470", "segment_start_timestamp_in_seconds": "66", "segment_end_timestamp_in_seconds": "194", "video_id": "vi31gHvd0MMz8FonUstjUyMe", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is facilitating the conversation and prompting Bill Landi to express his concerns, rather than giving or receiving feedback.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not the primary person giving or receiving feedback in this interaction. Instead, he is facilitating the conversation by prompting Bill Landi to share his concerns.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi31gHvd0MMz8FonUstjUyMe#;t=66", "type": "feedback"}, {"index": "vi31gHvd0MMz8FonUstjUyMe_Feedback_2", "sequence_id": "2", "segment_id_sequence_start": "21", "segment_id_sequence_end": "23", "summary": "Bill and Kanishka discuss the need for a flexible roadmap that allows for adjustments while still providing direction, highlighting the importance of proactive planning.", "title": "Need for Flexible Roadmap", "segment_start_timestamp": "07:18.943", "segment_end_timestamp": "08:52.099", "segment_start_timestamp_in_seconds": "438", "segment_end_timestamp_in_seconds": "532", "video_id": "vi31gHvd0MMz8FonUstjUyMe", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is not the primary person giving or receiving feedback in this interaction. The discussion is focused on roadmaps and project management without Kanishka providing or receiving specific feedback.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not the primary person giving or receiving feedback in this interaction. The discussion is focused on roadmaps and project management without Kanishka providing or receiving specific feedback.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi31gHvd0MMz8FonUstjUyMe#;t=438", "type": "feedback"}, {"index": "vi31gHvd0MMz8FonUstjUyMe_Feedback_3", "sequence_id": "3", "segment_id_sequence_start": "26", "segment_id_sequence_end": "29", "summary": "Kanishka raises concerns about the organization\'s focus on specific diseases driven by pharma, while Bill agrees and emphasizes the need to prioritize areas that align with their vision.", "title": "Focus on Pharma vs. Vision", "segment_start_timestamp": "11:18.783", "segment_end_timestamp": "14:05.076", "segment_start_timestamp_in_seconds": "678", "segment_end_timestamp_in_seconds": "845", "video_id": "vi31gHvd0MMz8FonUstjUyMe", "activity_type": "Constructive Feedback", "activity_reasoning": "Kanishka Rao is receiving constructive feedback from Bill Landi, who expresses concerns about the current strategy and its implications, suggesting that the focus on AstraZeneca may not align with the overall goals of the organization.", "target_person_type": "Receiving Feedback", "target_person_reasoning": "Kanishka Rao is receiving feedback in this case as Bill Landi expresses concerns and suggestions regarding the strategy and its implications, which Kanishka is responding to and reflecting on.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi31gHvd0MMz8FonUstjUyMe#;t= ...
# Updated metadata for video vi31gHvd0MMz8FonUstjUyMe
# []
# {'videoId': 'vi18qSrl7wIdeYOKuDg7YQBx', 'title': 'Kanishka / Kareem', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-10-08T20:22:18+00:00', 'createdAt': '2024-10-08T20:22:18+00:00', 'updatedAt': '2024-10-15T19:27:57+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'activities', 'value': '[{"index": "vi18qSrl7wIdeYOKuDg7YQBx_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "4", "segment_id_sequence_end": "5", "summary": "Kareem expresses the need to validate areas where they can assist, emphasizing the importance of Doctor Harvey\'s input and the need for an interactive session to engage him effectively.", "title": "Engaging Doctor Harvey\'s Input", "segment_start_timestamp": "07:07.860", "segment_end_timestamp": "08:04.900", "segment_start_timestamp_in_seconds": "427", "segment_end_timestamp_in_seconds": "484", "video_id": "vi18qSrl7wIdeYOKuDg7YQBx", "activity_type": "Guidance", "activity_reasoning": "Kanishka Rao is providing specific suggestions on how to structure the presentation slides, indicating they are offering advice and direction to help improve the presentation strategy.", "target_person_type": "Giving Feedback", "target_person_reasoning": "Kanishka Rao is the primary person giving feedback in this case because they directly suggest building up a slide and provide specific guidance on how to present the information, indicating they are actively giving feedback on the presentation strategy.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi18qSrl7wIdeYOKuDg7YQBx#;t=427", "type": "feedback"}, {"index": "vi18qSrl7wIdeYOKuDg7YQBx_Feedback_2", "sequence_id": "2", "segment_id_sequence_start": "8", "segment_id_sequence_end": "10", "summary": "Kareem and Kanishka discuss the necessity of an executive summary for the presentation, with Kanishka advocating for its inclusion to facilitate the conversation.", "title": "Importance of Executive Summary", "segment_start_timestamp": "08:42.386", "segment_end_timestamp": "09:02.826", "segment_start_timestamp_in_seconds": "522", "segment_end_timestamp_in_seconds": "542", "video_id": "vi18qSrl7wIdeYOKuDg7YQBx", "activity_type": "Guidance", "activity_reasoning": "Kanishka Rao is providing guidance by suggesting the need for an executive summary to facilitate the conversation, indicating a direction for the team to follow.", "target_person_type": "Giving Feedback", "target_person_reasoning": "Kanishka Rao is giving feedback by stating \'I think we should have one, just to start the conversation so he knows what\'s up...\' which indicates he is providing his perspective and guidance on the need for an executive summary.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi18qSrl7wIdeYOKuDg7YQBx#;t=522", "type": "feedback"}, {"index": "vi18qSrl7wIdeYOKuDg7YQBx_Feedback_3", "sequence_id": "3", "segment_id_sequence_start": "11", "segment_id_sequence_end": "13", "summary": "Kanishka emphasizes the need for a level-setting slide to clarify their mission and objectives before diving into the agenda, ensuring Doctor Harvey understands their purpose.", "title": "Clarifying Mission and Objectives", "segment_start_timestamp": "09:35.986", "segment_end_timestamp": "10:04.196", "segment_start_timestamp_in_seconds": "575", "segment_end_timestamp_in_seconds": "604", "video_id": "vi18qSrl7wIdeYOKuDg7YQBx", "activity_type": "Guidance", "activity_reasoning": "Kanishka Rao is providing guidance on how to structure the meeting by suggesting a level-setting slide and emphasizing the importance of communicating the mission and purpose, which helps direct the flow of the meeting.", "target_person_type": "Giving Feedback", "target_person_reasoning": "Kanishka Rao is providing feedback on the meeting structure and context by suggesting a level-setting slide and emphasizing the importance of communicating the mission and purpose of the meeting, indicating he is the primary actor in this interaction.", "act ...
# Updated metadata for video vi18qSrl7wIdeYOKuDg7YQBx
# []
# {'videoId': 'vi3MC0JsaO4n4cA7cYgYzpb4', 'title': 'Efficiency Meeting', 'description': '', 'public': True, 'panoramic': False, 'mp4Support': True, 'publishedAt': '2024-09-28T17:50:25+00:00', 'createdAt': '2024-09-28T17:50:25+00:00', 'updatedAt': '2024-10-15T19:27:58+00:00', 'tags': ['Kanishka Rao'], 'metadata': [{'key': 'activities', 'value': '[{"index": "vi3MC0JsaO4n4cA7cYgYzpb4_Feedback_1", "sequence_id": "1", "segment_id_sequence_start": "12", "segment_id_sequence_end": "25", "summary": "Sriram provides updates on meetings and discusses the importance of moving forward with Temple and MUSC, while Bharat emphasizes the need for careful communication regarding project delays.", "title": "Updates on Meetings and Strategy", "segment_start_timestamp": "02:26.420", "segment_end_timestamp": "05:50.953", "segment_start_timestamp_in_seconds": "146", "segment_end_timestamp_in_seconds": "350", "video_id": "vi3MC0JsaO4n4cA7cYgYzpb4", "activity_type": "Guidance", "activity_reasoning": "Kanishka Rao suggests scheduling a meeting to discuss how to incentivize the two individuals involved, indicating he is providing guidance on the next steps and emphasizing the urgency of the situation.", "target_person_type": "Giving Feedback", "target_person_reasoning": "Kanishka Rao is giving feedback in this case as he suggests scheduling a meeting to discuss how to incentivize the two individuals involved, indicating he is providing guidance on the next steps and emphasizing the urgency of the situation.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi3MC0JsaO4n4cA7cYgYzpb4#;t=146", "type": "feedback"}, {"index": "vi3MC0JsaO4n4cA7cYgYzpb4_Feedback_2", "sequence_id": "2", "segment_id_sequence_start": "26", "segment_id_sequence_end": "30", "summary": "Bharat expresses concerns about relying on Tim for timing, while Sriram reassures that the timing is under their control, leading to a discussion on how to address potential issues.", "title": "Concerns About Project Timing", "segment_start_timestamp": "05:51.453", "segment_end_timestamp": "06:48.036", "segment_start_timestamp_in_seconds": "351", "segment_end_timestamp_in_seconds": "408", "video_id": "vi3MC0JsaO4n4cA7cYgYzpb4", "activity_type": "Not Feedback", "activity_reasoning": "Kanishka Rao is not mentioned in the interaction, and there is no indication of their involvement in the discussion.", "target_person_type": "Not Involved", "target_person_reasoning": "Kanishka Rao is not mentioned in the interaction, and there is no indication of their involvement in the discussion.", "activity": "Feedback", "Moment_url": "https://embed.api.video/vod/vi3MC0JsaO4n4cA7cYgYzpb4#;t=351", "type": "feedback"}]'}], 'source': {'type': 'upload', 'uri': '/videos/vi3MC0JsaO4n4cA7cYgYzpb4/source'}, 'language': None, 'languageOrigin': None, 'discarded': False, 'discardedAt': None, 'deletesAt': None, 'assets': {'iframe': '<iframe src="https://embed.api.video/vod/vi3MC0JsaO4n4cA7cYgYzpb4" width="100%" height="100%" frameborder="0" scrolling="no" allowfullscreen="true"></iframe>', 'player': 'https://embed.api.video/vod/vi3MC0JsaO4n4cA7cYgYzpb4', 'hls': 'https://vod.api.video/vod/vi3MC0JsaO4n4cA7cYgYzpb4/hls/manifest.m3u8', 'thumbnail': 'https://vod.api.video/vod/vi3MC0JsaO4n4cA7cYgYzpb4/thumbnail.jpg', 'mp4': 'https://vod.api.video/vod/vi3MC0JsaO4n4cA7cYgYzpb4/mp4/source.mp4'}}
# Updated metadata for video vi3MC0JsaO4n4cA7cYgYzpb4
